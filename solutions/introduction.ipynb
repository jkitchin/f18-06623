# %% [markdown]
# - ASSIGNMENT: introduction
# - POINTS: 1
# - CATEGORY: homework
# - RUBRIC: default
# - RUBRIC_CATEGORIES: technical, presentation
# - RUBRIC_WEIGHTS: 0.8, 0.2
# - DUEDATE: 2018-08-31 23:59:59
# - GRADER: John Kitchin

# %% [markdown]
# # text cells

# %% [markdown]
# Tell me something interesting about yourself in the next cell. You can convert it to a text cell by clicking in the cell, and then clicking on Cell -> Cell Type -> Markdown. When done, click Edit -> Insert Image and insert a recent picture of yourself.

# %% [markdown]
# I like to garden, and make jams, pickles and cheese. Here is a picture of my family:
# ![2017-11-19%2011.04.46.jpg](attachment:2017-11-19%2011.04.46.jpg)

# %% [markdown]
# In the next cell, describe your experience with programming for solving engineering problems. For example, what courses have you taken, or languages you know, etc.

# %% [markdown]
# I am most proficient in Python for solving engineering problems. I also like Emacs Lisp.

# %% [markdown]
# In the next cell, describe what you are most concerned about for this course.

# %% [markdown]
# I am most concerned that you all see that you cannot be a modern engineer without being able to create and communication computational solutions to engineering problems.

# %% [markdown]
# # Python cells

# %% [markdown]
# ## A string

# %% [markdown]
# Fix this cell so that it prints "Hello World."

# %%
print("Hello World.")
# Out:
# Hello World.

# %% [markdown]
# Many solutions failed to capitalize the words, and add the punctuation. Computers are notoriously inflexible in what they accept, and missing these details can cause code to not work.

# %% [markdown]
# ## A function

# %% [markdown]
# Define a function in this cell that implements $f(x) = x^2$. Print a few examples of how to use the function.

# %%
def f(x):
    return x**2

# %%
f(-1)
# Out:
# 1

# %%
f(2)
# Out:
# 4

# %% [markdown]
# ## A plot

# %% [markdown]
# Create a plot of $f(x) = x^2$ over the range $x=0..2$.

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

x = np.linspace(0, 2)
plt.plot(x, f(x))
plt.xlabel('x')
plt.ylabel('f(x)')
